# %% [markdown]
# # eXtreme Gradient Boosting - XGBoost
#
# XGBoost, GBM'in hız ve tahmin performansını arttırmak üzere optimize edilmiş; ölçeklenebilir ve farklı platformlara entegre edilebilir halidir.
#
# * R, Python, Hadoop, Scala, Julia ile kullanılabilir.
# * Hızlıdır.
# * Tahmin başarısı yüksektir.
# * Birçok kaggle yarışmasında başarısını kanıtlamıştır.

# %% [markdown]
# Hadoop, Scala dünyasına entegre edildiğinde daha performanslı çalışır. (Hadoop cache bellek kullanır)

# %%
# bilgilerin gözükmesi için
from sklearn import set_config
set_config(print_changed_only=False)

# %% [markdown]
# # XGBoost - Model & Tahmin

# %%
import pandas as pd
# veri setimizi import edelim
diabetes = pd.read_csv("diabetes.csv")

# %%
df = diabetes.copy()
df = df.dropna()
y = df["Outcome"]
X = df.drop(["Outcome"], axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.30,
                                                   random_state=42)

# %%
from xgboost import XGBClassifier

# %%
# model kurulumu
xgb_model = XGBClassifier().fit(X_train, y_train)

# %%
# y test tahmin değerleri
y_pred = xgb_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
# doğruluk oranı
accuracy_score(y_test, y_pred)
# Out:
# 0.7359307359307359

# %% [markdown]
# # XGBoost - Model Tuning

# %%
xgb_model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='binary:logistic', predictor=None, ...)

# %%
# ?xgb_model
# Out:
# Type:        XGBClassifier
# String form:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#            colsample_bylevel=None <...> obs=None, num_parallel_tree=None,
#            objective='binary:logistic', predictor=None, ...)
# File:        /opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py
# Docstring:
# Implementation of the scikit-learn API for XGBoost classification.
#
#
# Parameters
# ----------
#
#     n_estimators : int
#         Number of boosting rounds.
#
#     max_depth :  Optional[int]
#         Maximum tree depth for base learners.
#     max_leaves :
#         Maximum number of leaves; 0 indicates no limit.
#     max_bin :
#         If using histogram-based algorithm, maximum number of bins per feature
#     grow_policy :
#         Tree growing policy. 0: favor splitting at nodes closest to the node, i.e. grow
#         depth-wise. 1: favor splitting at nodes with highest loss change.
#     learning_rate : Optional[float]
#         Boosting learning rate (xgb's "eta")
#     verbosity : Optional[int]
#         The degree of verbosity. Valid values are 0 (silent) - 3 (debug).
#     objective : typing.Union[str, typing.Callable[[numpy.ndarray, numpy.ndarray], typing.Tuple[numpy.ndarray, numpy.ndarray]], NoneType]
#         Specify the learning task and the corresponding learning objective or
#         a custom objective function to be used (see note below).
#     booster: Optional[str]
#         Specify which booster to use: gbtree, gblinear or dart.
#     tree_method: Optional[str]
#         Specify which tree method to use.  Default to auto.  If this parameter is set to
#         default, XGBoost will choose the most conservative option available.  It's
#         recommended to study this option from the parameters document :doc:`tree method
#         </treemethod>`
#     n_jobs : Optional[int]
#         Number of parallel threads used to run xgboost.  When used with other
#         Scikit-Learn algorithms like grid search, you may choose which algorithm to
#         parallelize and balance the threads.  Creating thread contention will
#         significantly slow down both algorithms.
#     gamma : Optional[float]
#         (min_split_loss) Minimum loss reduction required to make a further partition on a
#         leaf node of the tree.
#     min_child_weight : Optional[float]
#         Minimum sum of instance weight(hessian) needed in a child.
#     max_delta_step : Optional[float]
#         Maximum delta step we allow each tree's weight estimation to be.
#     subsample : Optional[float]
#         Subsample ratio of the training instance.
#     sampling_method :
#         Sampling method. Used only by `gpu_hist` tree method.
#           - `uniform`: select random training instances uniformly.
#           - `gradient_based` select random training instances with higher probability when
#             the gradient and hessian are larger. (cf. CatBoost)
#     colsample_bytree : Optional[float]
#         Subsample ratio of columns when constructing each tree.
#     colsample_bylevel : Optional[float]
#         Subsample ratio of columns for each level.
#     colsample_bynode : Optional[float]
#         Subsample ratio of columns for each split.
#     reg_alpha : Optional[float]
#         L1 regularization term on weights (xgb's alpha).
#     reg_lambda : Optional[float]
#         L2 regularization term on weights (xgb's lambda).
#     scale_pos_weight : Optional[float]
#         Balancing of positive and negative weights.
#     base_score : Optional[float]
#         The initial prediction score of all instances, global bias.
#     random_state : Optional[Union[numpy.random.RandomState, int]]
#         Random number seed.
#
#         .. note::
#
#            Using gblinear booster with shotgun updater is nondeterministic as
#            it uses Hogwild algorithm.
#
#     missing : float, default np.nan
#         Value in the data which needs to be present as a missing value.
#     num_parallel_tree: Optional[int]
#         Used for boosting random forest.
#     monotone_constraints : Optional[Union[Dict[str, int], str]]
#         Constraint of variable monotonicity.  See :doc:`tutorial </tutorials/monotonic>`
#         for more information.
#     interaction_constraints : Optional[Union[str, List[Tuple[str]]]]
#         Constraints for interaction representing permitted interactions.  The
#         constraints must be specified in the form of a nested list, e.g. ``[[0, 1], [2,
#         3, 4]]``, where each inner list is a group of indices of features that are
#         allowed to interact with each other.  See :doc:`tutorial
#         </tutorials/feature_interaction_constraint>` for more information
#     importance_type: Optional[str]
#         The feature importance type for the feature_importances\_ property:
#
#         * For tree model, it's either "gain", "weight", "cover", "total_gain" or
#           "total_cover".
#         * For linear model, only "weight" is defined and it's the normalized coefficients
#           without bias.
#
#     gpu_id : Optional[int]
#         Device ordinal.
#     validate_parameters : Optional[bool]
#         Give warnings for unknown parameter.
#     predictor : Optional[str]
#         Force XGBoost to use specific predictor, available choices are [cpu_predictor,
#         gpu_predictor].
#     enable_categorical : bool
#
#         .. versionadded:: 1.5.0
#
#         .. note:: This parameter is experimental
#
#         Experimental support for categorical data.  When enabled, cudf/pandas.DataFrame
#         should be used to specify categorical data type.  Also, JSON/UBJSON
#         serialization format is required.
#
#     feature_types : FeatureTypes
#
#         .. versionadded:: 1.7.0
#
#         Used for specifying feature types without constructing a dataframe. See
#         :py:class:`DMatrix` for details.
#
#     max_cat_to_onehot : Optional[int]
#
#         .. versionadded:: 1.6.0
#
#         .. note:: This parameter is experimental
#
#         A threshold for deciding whether XGBoost should use one-hot encoding based split
#         for categorical data.  When number of categories is lesser than the threshold
#         then one-hot encoding is chosen, otherwise the categories will be partitioned
#         into children nodes. Also, `enable_categorical` needs to be set to have
#         categorical feature support. See :doc:`Categorical Data
#         </tutorials/categorical>` and :ref:`cat-param` for details.
#
#     max_cat_threshold : Optional[int]
#
#         .. versionadded:: 1.7.0
#
#         .. note:: This parameter is experimental
#
#         Maximum number of categories considered for each split. Used only by
#         partition-based splits for preventing over-fitting. Also, `enable_categorical`
#         needs to be set to have categorical feature support. See :doc:`Categorical Data
#         </tutorials/categorical>` and :ref:`cat-param` for details.
#
#     eval_metric : Optional[Union[str, List[str], Callable]]
#
#         .. versionadded:: 1.6.0
#
#         Metric used for monitoring the training result and early stopping.  It can be a
#         string or list of strings as names of predefined metric in XGBoost (See
#         doc/parameter.rst), one of the metrics in :py:mod:`sklearn.metrics`, or any other
#         user defined metric that looks like `sklearn.metrics`.
#
#         If custom objective is also provided, then custom metric should implement the
#         corresponding reverse link function.
#
#         Unlike the `scoring` parameter commonly used in scikit-learn, when a callable
#         object is provided, it's assumed to be a cost function and by default XGBoost will
#         minimize the result during early stopping.
#
#         For advanced usage on Early stopping like directly choosing to maximize instead of
#         minimize, see :py:obj:`xgboost.callback.EarlyStopping`.
#
#         See :doc:`Custom Objective and Evaluation Metric </tutorials/custom_metric_obj>`
#         for more.
#
#         .. note::
#
#              This parameter replaces `eval_metric` in :py:meth:`fit` method.  The old one
#              receives un-transformed prediction regardless of whether custom objective is
#              being used.
#
#         .. code-block:: python
#
#             from sklearn.datasets import load_diabetes
#             from sklearn.metrics import mean_absolute_error
#             X, y = load_diabetes(return_X_y=True)
#             reg = xgb.XGBRegressor(
#                 tree_method="hist",
#                 eval_metric=mean_absolute_error,
#             )
#             reg.fit(X, y, eval_set=[(X, y)])
#
#     early_stopping_rounds : Optional[int]
#
#         .. versionadded:: 1.6.0
#
#         Activates early stopping. Validation metric needs to improve at least once in
#         every **early_stopping_rounds** round(s) to continue training.  Requires at least
#         one item in **eval_set** in :py:meth:`fit`.
#
#         The method returns the model from the last iteration (not the best one).  If
#         there's more than one item in **eval_set**, the last entry will be used for early
#         stopping.  If there's more than one metric in **eval_metric**, the last metric
#         will be used for early stopping.
#
#         If early stopping occurs, the model will have three additional fields:
#         :py:attr:`best_score`, :py:attr:`best_iteration` and
#         :py:attr:`best_ntree_limit`.
#
#         .. note::
#
#             This parameter replaces `early_stopping_rounds` in :py:meth:`fit` method.
#
#     callbacks : Optional[List[TrainingCallback]]
#         List of callback functions that are applied at end of each iteration.
#         It is possible to use predefined callbacks by using
#         :ref:`Callback API <callback_api>`.
#
#         .. note::
#
#            States in callback are not preserved during training, which means callback
#            objects can not be reused for multiple training sessions without
#            reinitialization or deepcopy.
#
#         .. code-block:: python
#
#             for params in parameters_grid:
#                 # be sure to (re)initialize the callbacks before each run
#                 callbacks = [xgb.callback.LearningRateScheduler(custom_rates)]
#                 xgboost.train(params, Xy, callbacks=callbacks)
#
#     kwargs : dict, optional
#         Keyword arguments for XGBoost Booster object.  Full documentation of parameters
#         can be found :doc:`here </parameter>`.
#         Attempting to set a parameter via the constructor args and \*\*kwargs
#         dict simultaneously will result in a TypeError.
#
#         .. note:: \*\*kwargs unsupported by scikit-learn
#
#             \*\*kwargs is unsupported by scikit-learn.  We do not guarantee
#             that parameters passed via this argument will interact properly
#             with scikit-learn.
#
#         .. note::  Custom objective function
#
#             A custom objective function can be provided for the ``objective``
#             parameter. In this case, it should have the signature
#             ``objective(y_true, y_pred) -> grad, hess``:
#
#             y_true: array_like of shape [n_samples]
#                 The target values
#             y_pred: array_like of shape [n_samples]
#                 The predicted values
#
#             grad: array_like of shape [n_samples]
#                 The value of the gradient for each sample point.
#             hess: array_like of shape [n_samples]
#                 The value of the second derivative for each sample point

# %%
# denenecek olan değerler
xgb_params ={
    "n_estimators": [100, 500, 1000, 2000],
    "subsample": [0.6, 0.8, 1.0],
    "max_depth": [3,4,5,6],
    "learning_rate": [0.1, 0.01, 0.02, 0.05],
    "min_samples_split": [2,5,10]
}

# %%
# model nesnesi oluşturuldu
xgb = XGBClassifier()

# %%
# cv nesnesi
from sklearn.model_selection import GridSearchCV
xgb_cv_model = GridSearchCV(xgb, xgb_params, cv=10, n_jobs=-1, verbose=2)

# %%
# cv model kuruldu
xgb_cv_model.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 576 candidates, totalling 5760 fits
# [15:29:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [15:29:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=1.0; total time=   0.2s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.4s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.4s
# [15:29:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.3s
# [15:29:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=0.6; total time=   0.6s
# [15:29:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   0.7s
# [15:29:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=1.0; total time=   0.6s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:29:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.3s
# [15:29:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.3s
# [15:29:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.3s
# [15:29:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.3s
# [15:29:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   0.6s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   0.6s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:29:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.1s
# [15:29:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.1s
# [15:29:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.3s
# [15:29:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.3s
# [15:29:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.3s
# [15:29:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.3s
# [15:29:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=0.8; total time=   0.6s
# [15:29:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=0.8; total time=   0.7s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:29:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=1.0; total time=   0.2s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.3s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.3s
# [15:29:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.3s
# [15:29:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=0.6; total time=   0.6s
# [15:29:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   0.7s
# [15:29:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=1.0; total time=   0.6s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.0s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:29:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:29:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.3s
# [15:29:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.3s
# [15:29:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.3s
# [15:29:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.3s
# [15:29:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   0.6s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   0.6s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:29:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:29:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.3s
# [15:29:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.3s
# [15:29:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.3s
# [15:29:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.3s
# [15:29:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=0.8; total time=   0.7s
# [15:29:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=0.8; total time=   0.6s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:29:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=1.0; total time=   0.2s
# [15:29:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.4s
# [15:29:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.4s
# [15:29:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=2000, subsample=0.6; total time=   0.7s
# [15:29:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=2000, subsample=0.6; total time=   0.7s
# [15:29:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=500, subsample=1.0; total time=   0.2s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.4s
# [15:29:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.4s
# [15:29:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.3s
# [15:29:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=0.6; total time=   0.7s
# [15:29:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   0.7s
# [15:29:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=2, n_estimators=2000, subsample=1.0; total time=   0.6s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.2s
# [15:29:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.2s
# [15:29:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.3s
# [15:29:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.3s
# [15:29:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.3s
# [15:29:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.3s
# [15:29:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   0.7s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   0.6s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:29:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:29:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.2s
# [15:29:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.2s
# [15:29:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.3s
# [15:29:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.3s
# [15:29:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   0.7s
# [15:29:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   0.7s
# [15:29:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   0.6s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=3, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   0.6s
# [15:29:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:29:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:29:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.4s
# [15:29:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.4s
# [15:29:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.4s
# [15:29:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.4s
# [15:29:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   0.7s
# [15:29:43] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   0.7s
# [15:29:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:29:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:29:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.1, max_depth=4, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:29:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# ...
#
# [CV] END learning_rate=0.05, max_depth=4, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:32:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=4, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:32:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=4, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.2s
# [15:32:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=4, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.4s
# [15:32:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=4, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.4s
# [15:32:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=4, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.4s
# [15:32:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=4, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   0.7s
# [15:32:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=4, min_samples_split=10, n_estimators=2000, subsample=0.8; total time=   0.8s
# [15:32:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=4, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   0.8s
# [15:32:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:32:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:32:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:32:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:32:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:32:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.4s
# [15:32:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.5s
# [15:32:43] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:32:43] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:32:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   0.8s
# [15:32:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   0.9s
# [15:32:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:32:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:32:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:32:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:32:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [15:32:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:32:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:32:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:32:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.2s
# [15:32:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.4s
# [15:32:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.4s
# [15:32:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:32:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:32:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   0.8s
# [15:32:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=2000, subsample=1.0; total time=   0.9s
# [15:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:32:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.2s
# [15:32:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.2s
# [15:32:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:32:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:32:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:32:54] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:32:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   0.8s
# [15:32:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   0.9s
# [15:33:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
# GridSearchCV(cv=10,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.01, 0.02, 0.05],
#                          'max_depth': [3, 4, 5, 6],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 500, 1000, 2000],
#                          'subsample': [0.6, 0.8, 1.0]},
#              verbose=2)

# %%
# bulunan en iyi parametrelere bakalım
xgb_cv_model.best_params_
# Out:
# {'learning_rate': 0.02,
#  'max_depth': 3,
#  'min_samples_split': 2,
#  'n_estimators': 100,
#  'subsample': 0.6}

# %%
# final modelimizi optimum parametrelerle oluşturalım
xgb = XGBClassifier(learning_rate = 0.02,
                   max_depth=3,
                   min_samples_split=2,
                   n_estimators=100,
                   subsample=0.6)

# %%
# modeli kurdum
xgb_tuned = xgb.fit(X_train, y_train)
# Out:
# [15:37:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [15:32:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.2s
# [15:32:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.5s
# [15:32:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:32:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:32:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:32:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   0.8s
# [15:32:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=2000, subsample=1.0; total time=   0.9s
# [15:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.0s
# [15:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:32:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.2s
# [15:32:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:32:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:32:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:32:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:32:54] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:32:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   0.8s
# [15:32:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   0.9s
# [15:32:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:32:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:32:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.5s
# [15:32:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:32:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:32:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=0.6; total time=   0.9s
# [15:32:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   0.8s
# [15:33:00] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=1.0; total time=   0.9s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:33:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:33:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.5s
# [15:33:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:33:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:33:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:33:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   0.8s
# [15:33:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=1.0; total time=   0.8s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.3s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:33:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:33:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:33:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:33:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:33:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:33:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:33:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   0.9s
# [15:32:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.3s
# [15:32:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.3s
# [15:32:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:32:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:32:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:32:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.5s
# [15:32:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:32:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:32:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:32:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   0.8s
# [15:33:00] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=1.0; total time=   0.9s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:33:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:33:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.5s
# [15:33:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:33:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:33:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:33:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   0.9s
# [15:33:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=1.0; total time=   0.9s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:33:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:33:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:33:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:33:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:33:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:33:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:33:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   0.9s
# [15:32:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:32:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:32:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:32:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   0.8s
# [15:32:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=2000, subsample=1.0; total time=   0.8s
# [15:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.0s
# [15:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.0s
# [15:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:32:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:32:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.5s
# [15:32:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.4s
# [15:32:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:32:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:32:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=2000, subsample=0.8; total time=   0.8s
# [15:32:54] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=10, n_estimators=2000, subsample=0.8; total time=   0.8s
# [15:32:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:32:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:32:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:32:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:32:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:32:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:32:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.3s
# [15:32:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=0.6; total time=   0.3s
# [15:32:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:32:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:32:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.5s
# [15:32:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:32:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:32:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:32:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   0.8s
# [15:33:00] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=1.0; total time=   0.9s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:33:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:33:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.5s
# [15:33:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:33:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:33:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:33:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   0.8s
# [15:33:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=1.0; total time=   0.9s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.3s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:33:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:33:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:33:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:33:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:33:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:33:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:33:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   0.8s
# [15:32:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:32:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:32:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:32:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:32:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [15:32:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [15:32:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.2s
# [15:32:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:32:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.2s
# [15:32:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.4s
# [15:32:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:32:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=5, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:32:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# ...
# [15:33:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.5s
# [15:33:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:33:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:33:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:33:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   0.9s
# [15:33:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=1.0; total time=   0.9s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.3s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:33:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.5s
# [15:33:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.5s
# [15:33:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.6s
# [15:33:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:33:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=2000, subsample=0.8; total time=   0.8s
# [15:33:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=2000, subsample=0.8; total time=   0.9s
# [15:33:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   0.8s
# [15:32:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:32:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=0.6; total time=   0.5s
# [15:32:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:32:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:32:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:32:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=0.8; total time=   0.9s
# [15:33:00] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=2, n_estimators=2000, subsample=1.0; total time=   0.9s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [15:33:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:33:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=500, subsample=1.0; total time=   0.3s
# [15:33:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=0.6; total time=   0.4s
# [15:33:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=0.8; total time=   0.5s
# [15:33:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:33:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=0.6; total time=   0.8s
# [15:33:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=0.8; total time=   0.8s
# [15:33:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=5, n_estimators=2000, subsample=1.0; total time=   0.9s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=0.6; total time=   0.1s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=0.8; total time=   0.1s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=100, subsample=1.0; total time=   0.1s
# [15:33:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=0.6; total time=   0.4s
# [15:33:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=500, subsample=0.8; total time=   0.3s
# [15:33:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.5s
# [15:33:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=0.6; total time=   0.5s
# [15:33:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:33:08] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=1000, subsample=1.0; total time=   0.5s
# [15:33:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=2000, subsample=0.8; total time=   0.9s
# [15:33:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=2000, subsample=0.8; total time=   0.9s
# [15:33:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "min_samples_split" } are not used.
#
# [CV] END learning_rate=0.05, max_depth=6, min_samples_split=10, n_estimators=2000, subsample=1.0; total time=   0.8s

# %%
# tahmin edilen y test değerleri
y_pred = xgb_tuned.predict(X_test)

# %%
# doğruluk oranı
accuracy_score(y_test, y_pred)
# Out:
# 0.7575757575757576
